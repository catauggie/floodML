# %%
import os
import re
import pandas as pd

# Directory containing the .txt files
directory = r'C:\Users\ivan\WORK\ПАПАЙИ\Paper 5\individuals'

# List to store data from each file
data = []

# Regex patterns to match the parameters
patterns = {
    'num_layers': r'num_layers:\s*(\d+)',
    'neurons_per_layer': r'neurons_per_layer:\s*\[(.*?)\]',
    'activation_functions': r'activation_functions:\s*\[(.*?)\]',
    'optimizer': r'optimizer:\s*([a-zA-Z0-9_]+)',
    'alpha': r'alpha:\s*([\d.]+)',
    'loss_function': r'loss_function:\s*([a-zA-Z0-9_]+)',
    'accuracy': r'accuracy:\s*([\d.-]+)',
}

# Function to read and parse each file
def parse_txt_file(file_path):
    with open(file_path, 'r') as file:
        content = file.read()
        params = {}
        for key, pattern in patterns.items():
            match = re.search(pattern, content)
            if match:
                if key in ['neurons_per_layer', 'activation_functions']:
                    params[key] = eval('[' + match.group(1) + ']')
                else:
                    params[key] = match.group(1)
            else:
                params[key] = None
        return params

# Iterate over each file in the directory
for filename in os.listdir(directory):
    if filename.endswith('.txt') and 'params' in filename:
        file_path = os.path.join(directory, filename)
        params = parse_txt_file(file_path)
        params['filename'] = filename  # Add filename to parameters
        data.append(params)

# Convert the list of dictionaries to a DataFrame
df = pd.DataFrame(data)

# Define the order of columns as specified
desired_columns = ['num_layers', 'neurons_per_layer', 'activation_functions',
                   'optimizer', 'alpha', 'loss_function', 'accuracy', 'filename']
df = df[desired_columns]

# Remove rows with NaN values
df_ = df.dropna()

# Output Excel file path
output_excel_file = r'output.xlsx'

# Write DataFrame to Excel
df_.to_excel(output_excel_file, index=False)

print(f"Data has been successfully written to {output_excel_file}")
# Out:
# Data has been successfully written to output.xlsx

# %%
import os
import re
import pandas as pd

# Directory containing the .txt files
directory = r'C:\Users\ivan\WORK\ПАПАЙИ\Paper 5\individuals_Manila'

# List to store data from each file
data = []

# Regex patterns to match the parameters
patterns = {
    'num_layers': r'num_layers:\s*(\d+)',
    'neurons_per_layer': r'neurons_per_layer:\s*\[(.*?)\]',
    'activation_functions': r'activation_functions:\s*\[(.*?)\]',
    'optimizer': r'optimizer:\s*([a-zA-Z0-9_]+)',
    'alpha': r'alpha:\s*([\d.]+)',
    'loss_function': r'loss_function:\s*([a-zA-Z0-9_]+)',
    'accuracy': r'accuracy:\s*([\d.-]+)',
}

# Function to read and parse each file
def parse_txt_file(file_path):
    with open(file_path, 'r') as file:
        content = file.read()
        params = {}
        for key, pattern in patterns.items():
            match = re.search(pattern, content)
            if match:
                if key in ['neurons_per_layer', 'activation_functions']:
                    params[key] = eval('[' + match.group(1) + ']')
                else:
                    params[key] = match.group(1)
            else:
                params[key] = None
        return params

# Iterate over each file in the directory
for filename in os.listdir(directory):
    if filename.endswith('.txt') and 'params' in filename:
        file_path = os.path.join(directory, filename)
        params = parse_txt_file(file_path)
        params['filename'] = filename  # Add filename to parameters
        data.append(params)

# Convert the list of dictionaries to a DataFrame
df = pd.DataFrame(data)

# Define the order of columns as specified
desired_columns = ['num_layers', 'neurons_per_layer', 'activation_functions',
                   'optimizer', 'alpha', 'loss_function', 'accuracy', 'filename']
df = df[desired_columns]

# Remove rows with NaN values
df_ = df.dropna()

# Output Excel file path
output_excel_file = r'output_Manila.xlsx'

# Write DataFrame to Excel
df_.to_excel(output_excel_file, index=False)

print(f"Data has been successfully written to {output_excel_file}")
# Out:
# Data has been successfully written to output_Manila.xlsx

# %%
import os
import re
import pandas as pd

# Directory containing the .txt files
directory = r'C:\Users\ivan\WORK\ПАПАЙИ\Paper 5\individuals_Manila_5classes'

# List to store data from each file
data = []

# Regex patterns to match the parameters
patterns = {
    'num_layers': r'num_layers:\s*(\d+)',
    'neurons_per_layer': r'neurons_per_layer:\s*\[(.*?)\]',
    'activation_functions': r'activation_functions:\s*\[(.*?)\]',
    'optimizer': r'optimizer:\s*([a-zA-Z0-9_]+)',
    'alpha': r'alpha:\s*([\d.]+)',
    'loss_function': r'loss_function:\s*([a-zA-Z0-9_]+)',
    'accuracy': r'accuracy:\s*([\d.-]+)',
}

# Function to read and parse each file
def parse_txt_file(file_path):
    with open(file_path, 'r') as file:
        content = file.read()
        params = {}
        for key, pattern in patterns.items():
            match = re.search(pattern, content)
            if match:
                if key in ['neurons_per_layer', 'activation_functions']:
                    params[key] = eval('[' + match.group(1) + ']')
                else:
                    params[key] = match.group(1)
            else:
                params[key] = None
        return params

# Iterate over each file in the directory
for filename in os.listdir(directory):
    if filename.endswith('.txt') and 'params' in filename:
        file_path = os.path.join(directory, filename)
        params = parse_txt_file(file_path)
        params['filename'] = filename  # Add filename to parameters
        data.append(params)

# Convert the list of dictionaries to a DataFrame
df = pd.DataFrame(data)

# Define the order of columns as specified
desired_columns = ['num_layers', 'neurons_per_layer', 'activation_functions',
                   'optimizer', 'alpha', 'loss_function', 'accuracy', 'filename']
df = df[desired_columns]

# Remove rows with NaN values
df_ = df.dropna()

# Output Excel file path
output_excel_file = r'output_Manila_5classes.xlsx'

# Write DataFrame to Excel
df_.to_excel(output_excel_file, index=False)

print(f"Data has been successfully written to {output_excel_file}")
# Out:
# Data has been successfully written to output_Manila_5classes.xlsx

# %%
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_excel('output.xlsx')
df = df[df['accuracy'] >0.1].sort_values(by='accuracy', ascending=True)


# Строим график
plt.figure(figsize=(15, 8))

epochs = np.arange(df.shape[0])

# Кривые для validation
#plt.plot(epochs, df['f1_score'], marker='o', linestyle='-', color='blue', label='$F_1$ Score')
plt.plot(epochs, df['accuracy'], marker='o', linestyle='-', color='orange', label='Accuracy')
#plt.plot(epochs, df['precision'], marker='o', linestyle='-', color='green', label='Precision')
#plt.plot(epochs, df['recall'], marker='o', linestyle='-', color='red', label='Recall')

# Кривые для test
#plt.plot(epochs, df['test_accuracy'], marker='o', linestyle='-', color='red', label='test_accuracy')
#plt.plot(epochs, df['test_precision'], marker='o', linestyle='-', color='purple', label='test_precision')
#plt.plot(epochs, df['test_recall'], marker='o', linestyle='-', color='brown', label='test_recall')

# Добавление фона с номерами
#plt.axvspan(0, 19, color='blue', alpha=0.1, label='Generation 0')

for i in range(0, df.shape[0], 50):
    plt.axvspan(i, i + 50, color=plt.cm.tab20(i // 50), alpha=0.1, label=f'Generation {i // 50}')


# Настройки графика
plt.title('Accuracy Evolution')
plt.xlabel('Individuals')
plt.ylabel('Score')
plt.grid(True)
plt.legend()

# Отображение графика
plt.tight_layout()
plt.savefig('indiv.pdf')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_excel('output_Manila.xlsx')
df = df[df['accuracy'] >0.1].sort_values(by='accuracy', ascending=True)


# Строим график
plt.figure(figsize=(15, 8))

epochs = np.arange(df.shape[0])

# Кривые для validation
#plt.plot(epochs, df['f1_score'], marker='o', linestyle='-', color='blue', label='$F_1$ Score')
plt.plot(epochs, df['accuracy'], marker='o', linestyle='-', color='orange', label='Accuracy')
#plt.plot(epochs, df['precision'], marker='o', linestyle='-', color='green', label='Precision')
#plt.plot(epochs, df['recall'], marker='o', linestyle='-', color='red', label='Recall')

# Кривые для test
#plt.plot(epochs, df['test_accuracy'], marker='o', linestyle='-', color='red', label='test_accuracy')
#plt.plot(epochs, df['test_precision'], marker='o', linestyle='-', color='purple', label='test_precision')
#plt.plot(epochs, df['test_recall'], marker='o', linestyle='-', color='brown', label='test_recall')

# Добавление фона с номерами
#plt.axvspan(0, 19, color='blue', alpha=0.1, label='Generation 0')

for i in range(0, df.shape[0], 50):
    plt.axvspan(i, i + 50, color=plt.cm.tab20(i // 50), alpha=0.1, label=f'Generation {i // 50}')


# Настройки графика
plt.title('Accuracy Evolution')
plt.xlabel('Individuals')
plt.ylabel('Score')
plt.grid(True)
plt.legend()

# Отображение графика
plt.tight_layout()
plt.savefig('indiv_Manila.pdf')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_excel('output_Manila_5classes.xlsx')
df = df[df['accuracy'] >0.1].sort_values(by='accuracy', ascending=True)


# Строим график
plt.figure(figsize=(15, 8))

epochs = np.arange(df.shape[0])

# Кривые для validation
#plt.plot(epochs, df['f1_score'], marker='o', linestyle='-', color='blue', label='$F_1$ Score')
plt.plot(epochs, df['accuracy'], marker='o', linestyle='-', color='orange', label='Accuracy')
#plt.plot(epochs, df['precision'], marker='o', linestyle='-', color='green', label='Precision')
#plt.plot(epochs, df['recall'], marker='o', linestyle='-', color='red', label='Recall')

# Кривые для test
#plt.plot(epochs, df['test_accuracy'], marker='o', linestyle='-', color='red', label='test_accuracy')
#plt.plot(epochs, df['test_precision'], marker='o', linestyle='-', color='purple', label='test_precision')
#plt.plot(epochs, df['test_recall'], marker='o', linestyle='-', color='brown', label='test_recall')

# Добавление фона с номерами
#plt.axvspan(0, 19, color='blue', alpha=0.1, label='Generation 0')

for i in range(0, df.shape[0], 50):
    plt.axvspan(i, i + 50, color=plt.cm.tab20(i // 50), alpha=0.1, label=f'Generation {i // 50}')


# Настройки графика
plt.title('Accuracy Evolution')
plt.xlabel('Individuals')
plt.ylabel('Score')
plt.grid(True)
plt.legend()

# Отображение графика
plt.tight_layout()
plt.savefig('indiv_Manila_5classes.pdf')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

df = pd.read_excel('output.xlsx')
df = df[df['accuracy'] >0.2].sort_values(by='accuracy', ascending=True)

df_ = pd.read_excel('output_Manila.xlsx')
df_ = df_[df_['accuracy'] >0.2].sort_values(by='accuracy', ascending=True)

df5 = pd.read_excel('output_Manila_5classes.xlsx')
df5 = df5[df5['accuracy'] >0.1].sort_values(by='accuracy', ascending=True)

# Строим график
plt.figure(figsize=(15, 8))

epochs = np.arange(df.shape[0])
epochs_ = np.arange(df_.shape[0])
epochs5 = np.arange(df5.shape[0])

# Кривые для validation
#plt.plot(epochs, df['f1_score'], marker='o', linestyle='-', color='blue', label='$F_1$ Score')
plt.plot(epochs, df['accuracy'], marker='o', linestyle='-', color='green', label='Accuracy for Ibadan Floods\n(5 classes)')
plt.plot(epochs_, df_['accuracy'], marker='o', linestyle='-', color='red', label='Accuracy for Manila Floods\n(9 classes)')
plt.plot(epochs5, df5['accuracy'], marker='o', linestyle='-', color='pink', label='Accuracy for Manila Floods\n(5 classes)')
#plt.plot(epochs, df['recall'], marker='o', linestyle='-', color='red', label='Recall')

# Кривые для test
#plt.plot(epochs, df['test_accuracy'], marker='o', linestyle='-', color='red', label='test_accuracy')
#plt.plot(epochs, df['test_precision'], marker='o', linestyle='-', color='purple', label='test_precision')
#plt.plot(epochs, df['test_recall'], marker='o', linestyle='-', color='brown', label='test_recall')

# Добавление фона с номерами
#plt.axvspan(0, 19, color='blue', alpha=0.1, label='Generation 0')

for i in range(0, df.shape[0], 50):
    plt.axvspan(i, i + 50, color=plt.cm.tab20(i // 50), alpha=0.1, label=f'Generation {i // 50}')


# Настройки графика
plt.title('Accuracy Evolution')
plt.xlabel('Individuals')
plt.ylabel('Score')
plt.grid(True)
plt.legend()

# Отображение графика
plt.tight_layout()
plt.savefig('indiv_all+.pdf')
plt.show()

# %%
df_best = df[df['accuracy'] >0.98]
df_best
# Out:
#      num_layers                                  neurons_per_layer  \
# 310           3                                      [101, 23, 52]
# 319           1                                              [105]
# 506           2                                            [1, 46]
# 329          13  [84, 107, 35, 101, 48, 114, 124, 29, 49, 43, 1...
#
#                                   activation_functions optimizer   alpha  \
# 310                    ['softplus', 'sigmoid', 'tanh']   adagrad  0.1000
# 319                                   ['hard_sigmoid']    adamax  0.0100
# 506                                 ['linear', 'selu']      adam  0.0010
# 329  ['softplus', 'gelu', 'linear', 'linear', 'relu...     nadam  0.0001
#
#                 loss_function  accuracy                       filename
# 310  categorical_crossentropy  0.980033   individual_g0_i37_params.txt
# 319  categorical_crossentropy  0.983361  individual_g0_i388_params.txt
# 506  categorical_crossentropy  0.983361  individual_g0_i556_params.txt
# 329  categorical_crossentropy  0.985025  individual_g0_i397_params.txt

# %%
df5 = df5[df5['accuracy'] >0.99]
df5
# Out:
#      num_layers                  neurons_per_layer  \
# 576           8  [37, 102, 116, 9, 9, 39, 124, 20]
# 365           2                           [6, 106]
# 187           5              [96, 42, 99, 113, 24]
# 272           8  [113, 51, 60, 7, 24, 53, 70, 125]
#
#                                   activation_functions optimizer   alpha  \
# 576  ['softplus', 'relu', 'sigmoid', 'tanh', 'gelu'...   adagrad  0.1000
# 365                                 ['sigmoid', 'elu']     nadam  0.0010
# 187          ['elu', 'selu', 'softmax', 'elu', 'gelu']     nadam  0.0001
# 272  ['sigmoid', 'linear', 'hard_sigmoid', 'softsig...     nadam  0.0001
#
#                 loss_function  accuracy                       filename
# 576  categorical_crossentropy  0.990028  individual_g0_i619_params.txt
# 365  categorical_crossentropy  0.990028  individual_g0_i429_params.txt
# 187  categorical_crossentropy  0.990028  individual_g0_i269_params.txt
# 272  categorical_crossentropy  0.991453  individual_g0_i345_params.txt

# %%
df_best['neurons_per_layer'].iloc[-1]
# Out:
# '[84, 107, 35, 101, 48, 114, 124, 29, 49, 43, 123, 24, 97]'

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

# Example list of indices (replace with your actual list)
inds = [619, 429, 269, 345]#[291, 338]

# Create a figure and axis objects for subplots
fig, axes = plt.subplots(1, len(inds), figsize=(16, 4))

for idx, i in enumerate(inds):
    # Чтение данных из файла без заголовков
    file_path = f'individuals_Manila_5classes/individual_g0_i{i}_predictions.txt'
    data = pd.read_csv(file_path, header=None, sep=", ")

    # Присвоение названий колонкам
    data.columns = ['index', 'true', 'pred']

    # Извлечение истинных и предсказанных значений
    true_classes = data['true']
    predicted_classes = data['pred']

    # Вычисление матрицы конфузий
    conf_matrix = confusion_matrix(true_classes, predicted_classes)

    # Визуализация матрицы конфузий с помощью seaborn
    sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Greens', cbar=False, linewidths=0.5, linecolor='black', ax=axes[idx])
    axes[idx].set_xlabel('Predicted')
    axes[idx].set_ylabel('True')
    axes[idx].set_title(f'Confusion Matrix №{idx+1}')

# Adjust layout and display the subplots
plt.tight_layout()
plt.savefig('CMs5.pdf')
plt.show()
# Out:
# C:\Users\ivan\AppData\Local\Temp\ipykernel_5792\3598436318.py:15: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   data = pd.read_csv(file_path, header=None, sep=", ")
# C:\Users\ivan\AppData\Local\Temp\ipykernel_5792\3598436318.py:15: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   data = pd.read_csv(file_path, header=None, sep=", ")
# C:\Users\ivan\AppData\Local\Temp\ipykernel_5792\3598436318.py:15: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   data = pd.read_csv(file_path, header=None, sep=", ")
# C:\Users\ivan\AppData\Local\Temp\ipykernel_5792\3598436318.py:15: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   data = pd.read_csv(file_path, header=None, sep=", ")

# %%
inds = df5['filename'].str.extract('i(\d+)_', expand=False).tolist()
inds
# Out:
# ['619', '429', '269', '345']

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

# Example list of indices (replace with your actual list)
inds = [37, 388, 556, 397]#[291, 338]

# Create a figure and axis objects for subplots
fig, axes = plt.subplots(1, len(inds), figsize=(16, 4))

for idx, i in enumerate(inds):
    # Чтение данных из файла без заголовков
    file_path = f'individuals/individual_g0_i{i}_predictions.txt'
    data = pd.read_csv(file_path, header=None, sep=", ")

    # Присвоение названий колонкам
    data.columns = ['index', 'true', 'pred']

    # Извлечение истинных и предсказанных значений
    true_classes = data['true']
    predicted_classes = data['pred']

    # Вычисление матрицы конфузий
    conf_matrix = confusion_matrix(true_classes, predicted_classes)

    # Визуализация матрицы конфузий с помощью seaborn
    sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Greens', cbar=False, linewidths=0.5, linecolor='black', ax=axes[idx])
    axes[idx].set_xlabel('Predicted')
    axes[idx].set_ylabel('True')
    axes[idx].set_title(f'Confusion Matrix №{idx+1}')

# Adjust layout and display the subplots
plt.tight_layout()
plt.savefig('CMs.pdf')
plt.show()
# Out:
# C:\Users\ivan\AppData\Local\Temp\ipykernel_12720\825062331.py:15: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   data = pd.read_csv(file_path, header=None, sep=", ")
# C:\Users\ivan\AppData\Local\Temp\ipykernel_12720\825062331.py:15: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   data = pd.read_csv(file_path, header=None, sep=", ")
# C:\Users\ivan\AppData\Local\Temp\ipykernel_12720\825062331.py:15: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   data = pd.read_csv(file_path, header=None, sep=", ")
# C:\Users\ivan\AppData\Local\Temp\ipykernel_12720\825062331.py:15: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   data = pd.read_csv(file_path, header=None, sep=", ")

# %%
df_best_ = df_[df_['accuracy'] >0.375]
df_best_
# Out:
#      num_layers        neurons_per_layer  \
# 334           5     [21, 8, 28, 99, 124]
# 54            6  [71, 47, 54, 3, 61, 85]
#
#                                   activation_functions optimizer  alpha  \
# 334  ['linear', 'linear', 'softplus', 'linear', 'ta...   rmsprop  0.001
# 54   ['relu', 'softmax', 'linear', 'gelu', 'linear'...     nadam  0.010
#
#                 loss_function  accuracy                       filename
# 334  categorical_crossentropy  0.377493  individual_g0_i400_params.txt
# 54   categorical_crossentropy  0.387464  individual_g0_i149_params.txt

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

# Example list of indices (replace with your actual list)
inds = [149, 400]#[291, 338]

# Create a figure and axis objects for subplots
fig, axes = plt.subplots(1, len(inds), figsize=(12, 6))

for idx, i in enumerate(inds):
    # Чтение данных из файла без заголовков
    file_path = f'individuals_Manila/individual_g0_i{i}_predictions.txt'
    data = pd.read_csv(file_path, header=None, sep=", ")

    # Присвоение названий колонкам
    data.columns = ['index', 'true', 'pred']

    # Извлечение истинных и предсказанных значений
    true_classes = data['true']
    predicted_classes = data['pred']

    # Вычисление матрицы конфузий
    conf_matrix = confusion_matrix(true_classes, predicted_classes)

    # Визуализация матрицы конфузий с помощью seaborn
    sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Greens', cbar=False, linewidths=0.5, linecolor='black', ax=axes[idx])
    axes[idx].set_xlabel('Predicted')
    axes[idx].set_ylabel('True')
    axes[idx].set_title(f'Confusion Matrix №{idx+1}')

# Adjust layout and display the subplots
plt.tight_layout()
plt.savefig('CMs_Manila.pdf')
plt.show()
# Out:
# C:\Users\ivan\AppData\Local\Temp\ipykernel_7348\111785041.py:15: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   data = pd.read_csv(file_path, header=None, sep=", ")
# C:\Users\ivan\AppData\Local\Temp\ipykernel_7348\111785041.py:15: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   data = pd.read_csv(file_path, header=None, sep=", ")
